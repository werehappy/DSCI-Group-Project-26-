# %%
library(tidyverse)
library(cowplot)
library(scales)

# %%
white_wine_df <- read_delim("data/winequality-white.csv", delim = ";")

red_wine_df <- read_delim("data/winequality-red.csv", delim = ";")

white_wine_df

red_wine_df
# Out:
# Rows: 4898 Columns: 12
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ";"
# dbl (12): fixed acidity, volatile acidity, citric acid, residual sugar, chlo...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 1599 Columns: 12
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ";"
# dbl (12): fixed acidity, volatile acidity, citric acid, residual sugar, chlo...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#      fixed acidity volatile acidity citric acid residual sugar chlorides
# 1    7.0           0.27             0.36        20.70          0.045
# 2    6.3           0.30             0.34         1.60          0.049
# ...

# %%
abalone <- read_delim("data/abalone.data", delim = ",")
colnames(abalone) <- c("Sex", "Length", "Diameter", 
                      "Height", "Whole_weight", "Shucked_weight", "Visera_weight", "Shell_weight", "Rings")

abalone
# Out:
# Rows: 4176 Columns: 9
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (1): M
# dbl (8): 0.455, 0.365, 0.095, 0.514, 0.2245, 0.101, 0.15, 15
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#      Sex Length Diameter Height Whole_weight Shucked_weight Visera_weight
# 1    M   0.350  0.265    0.090  0.2255       0.0995         0.0485
# 2    F   0.530  0.420    0.135  0.6770       0.2565         0.1415
# 3    M   0.440  0.365    0.125  0.5160       0.2155         0.1140
# 4    I   0.330  0.255    0.080  0.2050       0.0895         0.0395
# 5    I   0.425  0.300    0.095  0.3515       0.1410         0.0775
# 6    F   0.530  0.415    0.150  0.7775       0.2370         0.1415
# 7    F   0.545  0.425    0.125  0.7680       0.2940         0.1495
# 8    M   0.475  0.370    0.125  0.5095       0.2165         0.1125
# ...

# %%
songs_df <- read_csv("data/songs_normalize.csv")
songs_df
# Out:
# Rows: 2000 Columns: 18
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (3): artist, song, genre
# dbl (14): duration_ms, year, popularity, danceability, energy, key, loudness...
# lgl  (1): explicit
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#      artist              song
# 1    Britney Spears      Oops!...I Did It Again
# 2    blink-182           All The Small Things
# 3    Faith Hill          Breathe
# 4    Bon Jovi            It's My Life
# 5    *NSYNC              Bye Bye Bye
# 6    Sisqo               Thong Song
# 7    Eminem              The Real Slim Shady
# 8    Robbie Williams     Rock DJ
# 9    Destiny's Child     Say My Name
# 10   Modjo               Lady - Hear Me Tonight
# 11   Gigi D'Agostino     L'Amour Toujours
# 12   Eiffel 65           Move Your Body - Gabry Ponte Original Radio Edit
# ...

# %%
songs_factor <- songs_df |> mutate(genre, as_factor(genre))

songs_select <- songs_factor |> group_by(popularity, genre) |> summarize

#songs_group_genre <- songs_select |> group_by(genre) |> summarize(genre)

#songs_group_genre

#songs_top10_genre <- songs_select |> arrange(genre, by =desc(popularity))
#songs_top10_genre
# Out:
# Warning message:
# “Returning more (or less) than 1 row per `summarise()` group was deprecated in
# dplyr 1.1.0.
# ℹ Please use `reframe()` instead.
# ℹ When switching from `summarise()` to `reframe()`, remember that `reframe()`
#   always returns an ungrouped data frame and adjust accordingly.”
# `summarise()` has grouped output by 'genre'. You can override using the
# `.groups` argument.
#      genre
# 1    Dance/Electronic
# 2    Dance/Electronic
# 3    Dance/Electronic
# 4    Dance/Electronic
# 5    Dance/Electronic
# 6    Dance/Electronic
# 7    Dance/Electronic
# 8    Dance/Electronic
# 9    Dance/Electronic
# 10   Dance/Electronic
# 11   Dance/Electronic
# 12   Dance/Electronic
# 13   Dance/Electronic
# 14   Dance/Electronic
# 15   Dance/Electronic
# 16   Dance/Electronic
# 17   Dance/Electronic
# 18   Dance/Electronic
# 19   Dance/Electronic
# 20   Dance/Electronic
# 21   Dance/Electronic
# 22   Dance/Electronic
# 23   Dance/Electronic
# 24   Dance/Electronic
# ...

# %%
songs_histogram <- songs_top10_genre |> ggplot(aes(x = genre)) +
    geom_histogram(stat="count")

songs_histogram
# Out:
# Warning message in geom_histogram(stat = "count"):
# “Ignoring unknown parameters: `binwidth`, `bins`, and `pad`”
# plot without title
